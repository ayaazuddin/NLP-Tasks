# %% [markdown]
# # 22/07/2022
# # Task-1

# %%
import nltk
from nltk.stem import PorterStemmer
stemmerporter = PorterStemmer()
stemmerporter.stem('happiness')
# Out:
# 'happi'

# %%
import nltk
from nltk.stem import LancasterStemmer
stemmerLan = LancasterStemmer()
stemmerLan.stem('happiness')
# Out:
# 'happy'

# %%
import nltk
from nltk.stem import RegexpStemmer
stemmerregexp = RegexpStemmer("ing")
stemmerregexp.stem('singing')
# Out:
# 's'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
french_stemmer = SnowballStemmer('french')
french_stemmer.stem("manges")
# Out:
# 'mang'

# %% [markdown]
# # Task-2

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
example = "The quick brown fox jumped over a lazy dog" 
example = [stemmer.stem(token) for token in example.split(" ")]
print(" ".join(example))
# Out:
# the quick brown fox jump over a lazi dog

# %% [markdown]
# # Task-3

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("Formulae"))
print(lemmatizer.lemmatize("better",pos = 'a'))
print(lemmatizer.lemmatize("am",pos = 'v'))
# Out:
# cactus
# Formulae
# good
# be

# %% [markdown]
# # Task-4

# %%
pip install jieba
# Out:
# ...
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314482 sha256=e507d30cdbc2c570a9e619bcd2601563c0569bc65b0bdcb98dec72c935ce7818
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\ca\38\d8\dfdfe73bec1d12026b30cb7ce8da650f3f0ea2cf155ea018ae
# Successfully built jieba
# ...

# %%
import jieba
seg = jieba.cut("者売北呼頭律根施読負烈保渡。健最石報新権気最納係洞際訴題。独理集上八感博東籍音聞止岸逆変嶋国段少。離記選米入局立映図供属限玲福当。陛予乳提邸山愛脱罪就登広読提券任。記進今量勢島載室続場季建出動治屈新。橋護節箕取右特多細伊足合使善護挙断約。妊万憲問台江北異未市件助史県。年上鉛著促車際天戸権招賞令制解熊断考限支。物悲注税客員考故焼提賞込威。康出渓品責意測監試聞市対禁海野試無料択。総物族画島表教工盛騒売未開花年低人。者州転権経禁表客監国教上車数読期。設良名購人改務海差図棋続逃婚製教夫掲城歳。木網食年代交阪面求府前元載壌数。業回性入乱題健打開広要政近定総供対。野示比馬果白区渡開動浮警携。承文松埼変禁平共細係花題重結円県。情段健言年話柿謙禁供活映考可医能描黙担神。輪前通世道属手樹室既再婚育愛氷地並。天戦真置鮮提害要求日全用夕制億久文下断内。特続巻査高校最狙市安笑皇結将中保名不教。法建車月転見回立記無疑向。択分断施視降議婚後京質無元園運栗知践。記問幕挙労中理小援日熱旧力茶引由右訳天問。之私務挙読磨斉源阪人想立因台。合期巣韓第玉絡苦礁売休覧治職。新協供熊開通試学時茨聞理。記文実告散就評発楽今際換格財成党県集読。最失小転年止川良違頂今蔵。著性済聞西容済率物告時更倉白愚。業涙各質稿浩合択分間近両川風究。納応便重帯持案労塔維強紙護。用伊嘉記理備疑意族定車年配宿稿治。県断亭定動禁宮道作依白情人情。舞獲特線議両行文雨本専清場治成理認文開残。球京入親題予格記改民会国岡。去求県厳口象提投開幅敏霊経取報。聞紙永世変抽弟見尾投見索太稿載週西紹。認時言夕探写現右育百右井。手積検増女備野好覧別棋形堀止類産無話権読。合体需気龍置安増細但狭書大学広時年子。禁島産断転連戒碁例掛士早氏正裁結。減国客設良職本情体最試島思。市保的山権書新名農佐朝横藍保。投後就供出田市式読支会次。矢碁亡院券吉属嶋承営覧不企情頭風外抱。氷野期上早月彩練声禁耐億江得。府害球権投極載在案自剰組養。張論健検購覧壊容花相府者激株。所教欠服殺求後谷開観初爆。専供呼図欧千近後注界員室。行訓得鈴株願著攻組退楽堀用問。市決景記査米演雪現族暴息出済年暴減徹秋険。属画格辺語芸熊題後究史主北制盟検誰深。顔演告呼村向諸生原敏齢第感。経新営取証育童決来初腐史貨線説調葉泉。操軽点善表使稿試際気棋地競消巣。意社所果答技接申投万行用験豊替座生信飛。星意拡応体森残左茶波写選全先鹿開任。稿主制象剛度天由入全伸区名読界。気周台打残労継風陽問立真。特摩得載自未頭司長中変人情。修主円動要央真試組件摂能訃用専。求前郎建限歳庫影済口転事午。手切経族時府位区族続軽番。可画流飾載海側展際終数読。奪載報朝美社報経二日平年港士刈。末詠能特堺元禁力給子敗澤共様。作損治目経約進身者鶴作韓金透府。年結毎時市概目臓概載重道害。里端今内通屋暮景憶話減事画容。住協募養験入決他円里心首陛力含顔広対方。裏出当患闘合食検五肉民紙海売目鉄用。政従笑心選逃京拓国訃三源原聞国重類宜穂。門案男君放野要送団座軽健緒面突固。員配長張功作追形多越求武図別速落牛朝。学也暮最府感転由改要検非万童著協管水黒。際位待不北仲択後達芸経育料画半質情座勢。針供同森憲折東井掲声試誌芸陽連音銀惑選社。帳清写事広読田投辺効回年掲要染。子半集権威村流携力場止療載庁態設本賞折作。画州割練手役星年気阪風要舎竹明院遇作。")
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Dell\AppData\Local\Temp\jieba.cache
# Loading model cost 0.852 seconds.
# Prefix dict has been built successfully.
# ...

# %% [markdown]
# # Task-5

# %%
texts =  """Lorem ipsum is a pseudo-Latin text used in web design, typography, layout, and printing in place of English to emphasise design elements over content. It's also called placeholder (or filler) text. It's a convenient tool for mock-ups. It helps to outline the visual elements of a document or presentation, eg typography, font, or layout. Lorem ipsum is mostly a part of a Latin text by the classical author and philosopher Cicero. Its words and letters have been changed by addition or removal, so to deliberately render its content nonsensical; it's not genuine, correct, or comprehensible Latin anymore. While lorem ipsum's still resembles classical Latin, it actually has no meaning whatsoever. As Cicero's text doesn't contain the letters K, W, or Z, alien to latin, these, and others are often inserted randomly to mimic the typographic appearence of European languages, as are digraphs not to be found in the original.""" 

for text in texts:
    sentences = nltk.sent_tokenize(texts)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = nltk.pos_tag(words)
        print(tagged)
# Out:
# [('Lorem', 'NNP'), ('ipsum', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('pseudo-Latin', 'JJ'), ('text', 'NN'), ('used', 'VBN'), ('in', 'IN'), ('web', 'JJ'), ('design', 'NN'), (',', ','), ('typography', 'NN'), (',', ','), ('layout', 'NN'), (',', ','), ('and', 'CC'), ('printing', 'NN'), ('in', 'IN'), ('place', 'NN'), ('of', 'IN'), ('English', 'NNP'), ('to', 'TO'), ('emphasise', 'VB'), ('design', 'NN'), ('elements', 'NNS'), ('over', 'IN'), ('content', 'NN'), ('.', '.')]
# [('It', 'PRP'), ("'s", 'VBZ'), ('also', 'RB'), ('called', 'VBN'), ('placeholder', 'NN'), ('(', '('), ('or', 'CC'), ('filler', 'NN'), (')', ')'), ('text', 'NN'), ('.', '.')]
# [('It', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('convenient', 'JJ'), ('tool', 'NN'), ('for', 'IN'), ('mock-ups', 'NNS'), ('.', '.')]
# ...
